# %%
import csv
import copy
import numpy as np
import pandas as pd

from IPython.display import display

import selfies as sf
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import MolFromSmiles as smi2mol
from rdkit.Chem import MolToSmiles as mol2smi

# %%
chembl_filtered_df = pd.read_csv('filtered_data/chembl_filtered_2.1.0_.csv')
chembl_filtered_df
# Out:
#          Unnamed: 0                                      selfies_2.1.0  \
# 0                 0  [C][C][=C][C][=C][C][=Branch1][Ring2][=C][Ring...
# 1                 1  [O][=C][Branch1][N][N][C][C][N][C][C][O][C][C]...
# 2                 2  [C][C][=Branch1][C][=O][C][N][C][=Branch1][C][...
# 3                 3  [C][O][C][=C][C][=C][C][Branch2][Ring2][#Branc...
# 4                 4  [C][O][C][=Branch1][C][=O][C][N][=N][N][Branch...
# ...             ...                                                ...
# 1179472     1179472  [N][C][=Branch1][C][=O][C][C][C][=C][C][=C][C]...
# 1179473     1179473  [C][C][=C][C][=C][Branch2][Ring1][S][S][=Branc...
# 1179474     1179474  [C][C][=Branch1][C][=O][N][C][C][Branch1][C][O...
# 1179475     1179475  [C][C][O][C][=C][C][=C][N][=C][Branch2][Ring2]...
# 1179476     1179476  [C][O][C][=C][C][=C][NH1][C][=Branch1][C][=O][...
#
#                                                     smiles
# 0        Cc1ccc2c(c1)sc1c(=O)[nH]c3ccc(C(=O)NCCCN(C)C)c...
# 1             O=C(NCCN1CCOCC1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1
# 2                   CC(=O)CN1C(=O)C2CC(O)CN2C(=O)c2ccccc21
# 3        COc1cccc(NC(=O)c2oc3ccccc3c2NC(=O)c2ccc3c(c2)O...
# 4        COC(=O)c1nnn(CC(=O)C(CC2CCNC2=O)NC(=O)C(C)NC(=...
# ...                                                    ...
# 1179472       NC(=O)CCc1ccc2c(c1)c(CCc1ccccc1)cn2-c1ccccc1
# 1179473    Cc1ccc(S(=O)(=O)NC(=O)Nc2ccc(S(N)(=O)=O)nc2)cc1
# 1179474  CC(=O)N1CC(O)CC1C(=O)NC(CCCN=C(N)N)C(=O)c1nc2c...
# 1179475  CCOc1ccc2nc(N(CCCN(C)C)C(=O)c3ccc(S(=O)(=O)N4C...
# 1179476  COc1ccc2[nH]c(=O)c3cc(CC(C#N)NC(=O)C4NC5CCC4C5...
#
# [1179477 rows x 3 columns]
