# %%
import pandas as pd

# %%
zinc_df = pd.read_csv('filtered_data/zinc250_selfies_2.1.0_.csv')
zinc_df
# Out:
#         Unnamed: 0                                      selfies_2.1.0  \
# 0                0  [C][C][Branch1][C][C][Branch1][C][C][C][=C][C]...
# 1                1  [C][C][C][C][Branch1][C][C][C][C][Branch2][Rin...
# 2                2  [N][#C][C][=C][C][=C][Branch2][Ring2][Ring2][C...
# 3                3  [C][C][O][C][=Branch1][C][=O][C][C][C][C][N][B...
# 4                4  [N][#C][C][=C][Branch2][Ring1][Ring1][S][C][C]...
# ...            ...                                                ...
# 249450      249450  [C][C][Branch1][C][C][C][C][C][Branch2][Ring1]...
# 249451      249451  [C][N][C][=C][N][=C][Ring1][Branch1][C][=Branc...
# 249452      249452  [C][C][=C][C][=C][Branch2][Ring1][#Branch1][N]...
# 249453      249453  [C][C][=C][C][Branch2][Ring1][#Branch1][C][=Br...
# 249454      249454  [O][=C][Branch2][Ring1][Branch1][C][C][Branch1...
#
#                                              canon_smiles  \
# 0                 CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1
# ...
