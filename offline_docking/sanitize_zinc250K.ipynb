# %%
import csv
import copy
import numpy as np
import pandas as pd

from IPython.display import display

import selfies as sf
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import MolFromSmiles as smi2mol
from rdkit.Chem import MolToSmiles as mol2smi

# %%
zinc_df = pd.read_csv('raw_data/250k_rndm_zinc_drugs_clean_3.csv')
zinc_df.replace('\n','', regex=True, inplace=True)

# %%
zinc_smiles = list(zinc_df.smiles)
zinc_canon_smiles = []

# %%
for i, smiles in enumerate(zinc_df.smiles):
    
    mol = smi2mol(smiles, sanitize=True)
    smiles_canon = mol2smi(mol, isomericSmiles=False, canonical=True)
    
    zinc_canon_smiles.append(smiles_canon)
    
    if i%10000==0:
        print(i)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000

# %%
zinc_df.insert(0, 'canon_smiles', zinc_canon_smiles, allow_duplicates = False)

# %%
zinc_selfies = []
for i, c_smiles in enumerate(zinc_df.canon_smiles):
    
    zinc_selfies.append(sf.encoder(c_smiles))
    
    if i%10000==0:
        print(i)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000

# %%
zinc_df.insert(0, 'selfies_' + sf.__version__, zinc_selfies, allow_duplicates=False)

# %%
zinc_df.to_csv('filtered_data/zinc250_selfies_' + sf.__version__ + '_.csv')

# %%
zinc_df
# Out:
#                                             selfies_2.1.0  \
# 0       [C][C][Branch1][C][C][Branch1][C][C][C][=C][C]...
# 1       [C][C][C][C][Branch1][C][C][C][C][Branch2][Rin...
# 2       [N][#C][C][=C][C][=C][Branch2][Ring2][Ring2][C...
# 3       [C][C][O][C][=Branch1][C][=O][C][C][C][C][N][B...
# 4       [N][#C][C][=C][Branch2][Ring1][Ring1][S][C][C]...
# ...                                                   ...
# 249450  [C][C][Branch1][C][C][C][C][C][Branch2][Ring1]...
# 249451  [C][N][C][=C][N][=C][Ring1][Branch1][C][=Branc...
# 249452  [C][C][=C][C][=C][Branch2][Ring1][#Branch1][N]...
# 249453  [C][C][=C][C][Branch2][Ring1][#Branch1][C][=Br...
# 249454  [O][=C][Branch2][Ring1][Branch1][C][C][Branch1...
#
#                                              canon_smiles  \
# 0                 CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1
# 1                      CC1CC(C)CC(Nc2cncc(-c3nncn3C)c2)C1
# 2        N#Cc1ccc(-c2ccc(OC(C(=O)N3CCCC3)c3ccccc3)cc2)cc1
# 3       CCOC(=O)C1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c2CCCC...
# 4       N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])C(C#N)C1...
# ...                                                   ...
# 249450       CC1(C)CCC(CNC(=O)Cn2ncc3ccccc3c2=O)c2ccccc21
# 249451  Cn1ccnc1C(=O)c1ccc(NC(=O)C2CCN(C(=O)C(C)(C)C)C...
# 249452             Cc1ccc(NC(=O)C(=O)N(C)Cc2ccccc2)c(C)c1
# 249453         Cc1cc(C(=O)Nc2ccc(OCC(N)=O)cc2)c(C)n1C1CC1
# 249454  O=C(CC(c1ccccc1)c1ccccc1)N1CCN(S(=O)(=O)c2cccc...
#
#                                                    smiles     logP       qed  \
# 0                 CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1  5.05060  0.702012
# 1            C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1  3.11370  0.928975
# 2       N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  4.96778  0.599682
# 3       CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  4.00022  0.690944
# 4       N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  3.60956  0.789027
# ...                                                   ...      ...       ...
# 249450   CC1(C)CC[C@H](CNC(=O)Cn2ncc3ccccc3c2=O)c2ccccc21  3.36790  0.745901
# 249451  Cn1ccnc1C(=O)c1ccc(NC(=O)C2CCN(C(=O)C(C)(C)C)C...  2.87430  0.799426
# 249452             Cc1ccc(NC(=O)C(=O)N(C)Cc2ccccc2)c(C)c1  2.90054  0.878086
# 249453         Cc1cc(C(=O)Nc2ccc(OCC(N)=O)cc2)c(C)n1C1CC1  2.55624  0.852917
# 249454  O=C(CC(c1ccccc1)c1ccccc1)N1CCN(S(=O)(=O)c2cccc...  3.64990  0.370287
#
#              SAS
# 0       2.084095
# 1       3.432004
# 2       2.470633
# 3       2.822753
# 4       4.035182
# ...          ...
# 249450  2.900726
# 249451  2.326627
# 249452  1.840642
# 249453  2.024638
# 249454  2.214249
#
# [249455 rows x 6 columns]
